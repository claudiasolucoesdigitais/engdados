# %%
import pandas as pd

# %%
print("Oi")
# Out:
# Oi

# %%
df = pd.read_csv('pedidos_ecommerce.csv')

# %%
# print(df)
df.head(10)
# Out:
#   pedido_id data_pedido cliente_id          cidade estado    categoria  \
# 0  PED00001  2024-02-22    CLI9935         Goiânia     GO       Roupas
# 1  PED00002  2024-11-04    CLI4257       São Paulo     SP       Livros
# 2  PED00003  2024-01-04    CLI7924  Belo Horizonte     MG    Alimentos
# 3  PED00004  2024-07-02    CLI5333        Salvador     BA     Calçados
# 4  PED00005  2024-10-09    CLI6925    Porto Alegre     RS   Brinquedos
# 5  PED00006  2024-02-21    CLI5554       Fortaleza     CE       Roupas
# 6  PED00007  2024-12-15    CLI2169         Goiânia     GO       Beleza
# 7  PED00008  2024-11-23    CLI4598   Florianópolis     SC     Calçados
# 8  PED00009  2024-02-03    CLI6155        Curitiba     PR  Eletrônicos
# 9  PED00010  2024-10-14    CLI5304          Manaus     AM   Brinquedos
#
#                produto  quantidade  preco_unitario  valor_total  desconto  \
# 0        Camiseta Polo           3           82.04       246.12      0.00
# ...

# %%
df.tail()
# Out:
#      pedido_id data_pedido cliente_id          cidade estado    categoria  \
# 4995  PED04996  2024-11-18    CLI1430  Rio de Janeiro     RJ  Informática
# 4996  PED04997  2024-02-01    CLI5667       Fortaleza     CE  Informática
# 4997  PED04998  2024-07-01    CLI3778       Fortaleza     CE       Livros
# 4998  PED04999  2024-06-05    CLI3543        Curitiba     PR    Alimentos
# 4999  PED05000  2024-03-02    CLI3363       São Paulo     SP  Eletrônicos
#
#                 produto  quantidade  preco_unitario  valor_total  desconto  \
# 4995        Mouse Gamer           2          293.68       587.36     35.78
# 4996   Teclado Mecanico           3          373.63      1120.89      0.00
# 4997  Python para Dados           4          100.78       403.12      0.00
# 4998   Whey Protein 2kg           3          129.27       387.81     37.74
# 4999     Smart TV 50pol           5         3037.80     15189.00      0.00
#
#       valor_final forma_pagamento    status
# ...

# %%
df.shape
# Out:
# (5000, 14)

# %%
df.dtypes
# Out:
# pedido_id              str
# data_pedido            str
# cliente_id             str
# cidade                 str
# estado                 str
# categoria              str
# produto                str
# quantidade           int64
# preco_unitario     float64
# valor_total        float64
# desconto           float64
# valor_final        float64
# forma_pagamento        str
# status                 str
# dtype: object

# %%
# Salvar dataframe em diversos froamtos de arquivo

# %%
import os
